# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('GSAF5.csv')

# %%
df.head()
# Out:
#     Case Number       Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex   ...  \
# 0  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M  ...
# 2  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 3                  Thirteenth Beach  Surfing  Rory Angiolella    M  ...
# 4                       Bells Beach  Surfing             male    M  ...
#
#     Species        Investigator or Source                        pdf  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5992 entries, 0 to 5991
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             5992 non-null   object
#  1   Date                    5992 non-null   object
#  2   Year                    5992 non-null   int64
#  3   Type                    5992 non-null   object
#  4   Country                 5949 non-null   object
#  5   Area                    5590 non-null   object
#  6   Location                5496 non-null   object
#  7   Activity                5465 non-null   object
#  8   Name                    5792 non-null   object
#  9   Sex                     5425 non-null   object
#  10  Age                     3311 non-null   object
#  11  Injury                  5965 non-null   object
#  12  Fatal (Y/N)             5973 non-null   object
#  13  Time                    2779 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Case Number                  0
# Date                         0
# Year                         0
# Type                         0
# Country                     43
# Area                       402
# Location                   496
# Activity                   527
# Name                       200
# Sex                        567
# Age                       2681
# Injury                      27
# Fatal (Y/N)                 19
# Time                      3213
# Species                   2934
# Investigator or Source      15
# pdf                          0
# href formula                 1
# href                         3
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               5991
# Unnamed: 23               5990
# dtype: int64

# %%
#Tirando columnas con demasiados nulos >3000
nulos_columnas = df.isnull().sum()
columnas_feas = list(nulos_columnas[nulos_columnas>3000].index)
columnas_feas
# Out:
# ['Time', 'Unnamed: 22', 'Unnamed: 23']

# %%
df = df.drop(columnas_feas, axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5992 entries, 0 to 5991
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             5992 non-null   object
#  1   Date                    5992 non-null   object
#  2   Year                    5992 non-null   int64
#  3   Type                    5992 non-null   object
#  4   Country                 5949 non-null   object
#  5   Area                    5590 non-null   object
#  6   Location                5496 non-null   object
#  7   Activity                5465 non-null   object
#  8   Name                    5792 non-null   object
#  9   Sex                     5425 non-null   object
#  10  Age                     3311 non-null   object
#  11  Injury                  5965 non-null   object
#  12  Fatal (Y/N)             5973 non-null   object
#  13  Species                 3058 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Case Number                  0
# Date                         0
# Year                         0
# Type                         0
# Country                     43
# Area                       402
# Location                   496
# Activity                   527
# Name                       200
# Sex                        567
# Age                       2681
# Injury                      27
# Fatal (Y/N)                 19
# Species                   2934
# Investigator or Source      15
# pdf                          0
# href formula                 1
# href                         3
# Case Number.1                0
# Case Number.2                0
# original order               0
# dtype: int64

# %%
df.describe()
# Out:
#               Year  original order
# count  5992.000000     5992.000000
# mean   1925.204606     2997.548899
# std     286.473712     1729.860210
# min       0.000000        2.000000
# 25%    1942.000000     1499.750000
# 50%    1975.000000     2997.500000
# 75%    2003.000000     4495.250000
# max    2016.000000     5993.000000

# %%
#Tirando columnas repetidas
df.drop(columns=['Case Number.1', 'Case Number.2'], inplace=True)

# %%
df.Type.value_counts()
# Out:
# Unprovoked      4386
# Provoked         557
# Invalid          519
# Sea Disaster     220
# Boat             200
# Boating          110
# Name: Type, dtype: int64

# %%
df.Country.value_counts()
# Out:
# USA                         2116
# AUSTRALIA                   1279
# SOUTH AFRICA                 565
# PAPUA NEW GUINEA             133
# NEW ZEALAND                  125
#                             ...
# NORTHERN MARIANA ISLANDS       1
# ICELAND                        1
# MAYOTTE                        1
# UNITED ARAB EMIRATES           1
# THE BALKANS                    1
# Name: Country, Length: 203, dtype: int64

# %%
df
# Out:
#        Case Number         Date  Year        Type             Country  \
# 0     2016.09.18.c    18-Sep-16  2016  Unprovoked                 USA
# 1     2016.09.18.b    18-Sep-16  2016  Unprovoked                 USA
# 2     2016.09.18.a    18-Sep-16  2016  Unprovoked                 USA
# 3       2016.09.17    17-Sep-16  2016  Unprovoked           AUSTRALIA
# 4       2016.09.15    16-Sep-16  2016  Unprovoked           AUSTRALIA
# ...            ...          ...   ...         ...                 ...
# 5987       ND.0005  Before 1903     0  Unprovoked           AUSTRALIA
# 5988       ND.0004  Before 1903     0  Unprovoked           AUSTRALIA
# 5989       ND.0003    1900-1905     0  Unprovoked                 USA
# 5990       ND.0002    1883-1889     0  Unprovoked              PANAMA
# 5991       ND.0001    1845-1853     0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5992 entries, 0 to 5991
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             5992 non-null   object
#  1   Date                    5992 non-null   object
#  2   Year                    5992 non-null   int64
#  3   Type                    5992 non-null   object
#  4   Country                 5949 non-null   object
#  5   Area                    5590 non-null   object
#  6   Location                5496 non-null   object
#  7   Activity                5465 non-null   object
#  8   Name                    5792 non-null   object
#  9   Sex                     5425 non-null   object
#  10  Age                     3311 non-null   object
#  11  Injury                  5965 non-null   object
#  12  Fatal (Y/N)             5973 non-null   object
#  13  Species                 3058 non-null   object
# ...

# %%
df.head()
# Out:
#     Case Number       Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex   Age  \
# 0  New Smyrna Beach, Volusia County  Surfing             male    M   16
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M   36
# 2  New Smyrna Beach, Volusia County  Surfing             male    M   43
# 3                  Thirteenth Beach  Surfing  Rory Angiolella    M  NaN
# 4                       Bells Beach  Surfing             male    M  NaN
#
#                                   Injury Fatal (Y/N)   Species   \
# 0                  Minor injury to thigh           N        NaN
# ...

# %%
df = df.rename(columns={'Sex ': 'Sex'}) #arreglando el espacio que tiene en el nombre

# %%
df.Sex.value_counts()
# Out:
# M      4835
# F       585
# M         2
# lli       1
# .         1
# N         1
# Name: Sex, dtype: int64

# %%
df[df.Sex == '.'] #son 3 personas
# Out:
#        Case Number                  Date  Year          Type  \
# 5201  1908.06.02.R  Reported 02-Jun-1908  1908  Sea Disaster
#
#                Country         Area Location Activity Name Sex  Age  \
# 5201  PAPUA NEW GUINEA  New Britain   Matupi        .  NaN   .  NaN
#
#                                                  Injury Fatal (Y/N)  \
# 5201  Remains of 3 humans recovered from shark, but ...           Y
#
#                        Species      Investigator or Source  \
# 5201  Allegedly a 33-foot shark  Taranaki Herald, 6/2/1908
#
#                           pdf  \
# 5201  1908.06.02.R-Matupi.pdf
#
#                                            href formula  \
# 5201  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href  original order
# 5201  http://sharkattackfile.net/spreadsheets/pdf_di...             792

# %%
df.loc[df.Sex=='.'] = 'Multiple'
df.loc[df.Name=='NaN'] = 'Multiple'
df.loc[df.Age=='.'] = 'Multiple'

# %%
df[df.Sex == 'lli']
# Out:
#        Case Number       Date  Year        Type Country        Area  \
# 1400  2004.11.11.b  11-Nov-04  2004  Unprovoked     USA  California
#
#                                             Location Activity        Name  \
# 1400  Bunkers, Humboldt Bay, Eureka, Humboldt County  Surfing  Brian Kang
#
#       Sex Age                              Injury Fatal (Y/N)  \
# 1400  lli  38  Lacerations to hand, knee & thigh            N
#
#                      Species             Investigator or Source  \
# 1400  5.5 m [18'] white shark  R. Collier, GSAF
#
#                         pdf  \
# 1400  2004.11.11.b-Kang.pdf
#
#                                            href formula  \
# 1400  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href original order
# 1400  http://sharkattackfile.net/spreadsheets/pdf_di...           4593

# %%
df[df.Sex == 'lli'] = 'M'

# %%
df.iloc[1400]
# Out:
# Case Number               M
# Date                      M
# Year                      M
# Type                      M
# Country                   M
# Area                      M
# Location                  M
# Activity                  M
# Name                      M
# Sex                       M
# Age                       M
# Injury                    M
# Fatal (Y/N)               M
# Species                   M
# Investigator or Source    M
# pdf                       M
# href formula              M
# href                      M
# original order            M
# Name: 1400, dtype: object

# %%
df.head()
# Out:
#     Case Number       Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex  Age  \
# 0  New Smyrna Beach, Volusia County  Surfing             male   M   16
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano   M   36
# 2  New Smyrna Beach, Volusia County  Surfing             male   M   43
# 3                  Thirteenth Beach  Surfing  Rory Angiolella   M  NaN
# 4                       Bells Beach  Surfing             male   M  NaN
#
#                                   Injury Fatal (Y/N)   Species   \
# 0                  Minor injury to thigh           N        NaN
# ...

# %%
df.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal (Y/N)', 'Species ',
#        'Investigator or Source', 'pdf', 'href formula', 'href',
#        'original order'],
#       dtype='object')

# %%
df['Fatal (Y/N)'].value_counts()
# Out:
# N           4314
# Y           1551
# UNKNOWN       94
#  N             8
# N              1
# F              1
# M              1
# #VALUE!        1
# Multiple       1
# n              1
# Name: Fatal (Y/N), dtype: int64

# %%
df.loc[df["Fatal (Y/N)"] == ' N', "Fatal (Y/N)"] = "N"
df.loc[df["Fatal (Y/N)"] == 'F', "Fatal (Y/N)"] = "Y"
df.loc[df["Fatal (Y/N)"] == 'N ', "Fatal (Y/N)"] = "N"
df.loc[df["Fatal (Y/N)"] == 'n', "Fatal (Y/N)"] = "N"
df.loc[df["Fatal (Y/N)"] == 'M', "Fatal (Y/N)"] = "Multiple"

# %%
df['Fatal (Y/N)'].value_counts()
# Out:
# N           4324
# Y           1552
# UNKNOWN       94
# Multiple       2
# #VALUE!        1
# Name: Fatal (Y/N), dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5992 entries, 0 to 5991
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             5992 non-null   object
#  1   Date                    5992 non-null   object
#  2   Year                    5992 non-null   object
#  3   Type                    5992 non-null   object
#  4   Country                 5949 non-null   object
#  5   Area                    5590 non-null   object
#  6   Location                5496 non-null   object
#  7   Activity                5465 non-null   object
#  8   Name                    5793 non-null   object
#  9   Sex                     5425 non-null   object
#  10  Age                     3312 non-null   object
#  11  Injury                  5965 non-null   object
#  12  Fatal (Y/N)             5973 non-null   object
#  13  Species                 3058 non-null   object
# ...

# %%
Outcome = df.to_csv('clean_sharks.csv')
